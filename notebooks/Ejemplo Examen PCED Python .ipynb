# %% [markdown]
# Claro, Roger. A continuación, te presento un ejemplo de examen para la certificación PCED™ – Certified Entry-Level Data Analyst with Python, basado en el temario oficial y en recursos disponibles en línea.
#
# ⸻
#
# 📝 Simulacro de Examen PCED – Ejemplo de Preguntas
#
# Duración estimada: 40 minutos
# Número de preguntas: 10 (el examen real contiene 40)
# Formato: Opción múltiple (una o varias respuestas correctas)
#
# ⸻
#
# Sección 1: Adquisición y Preprocesamiento de Datos
#
# 1. Tienes un conjunto de datos con una desviación estándar muy alta. ¿Qué indica esto sobre los datos?
#
# a) Los datos están distribuidos normalmente.
# b) Los puntos de datos están ampliamente dispersos.
# c) No hay valores atípicos en el conjunto de datos.
# d) El conjunto de datos tiene muchos valores duplicados.
# Respuesta correcta: b) Los puntos de datos están ampliamente dispersos.
#
# ⸻
#
# 2. ¿Cuál es la diferencia principal entre un DataFrame y una Series en Pandas? (Selecciona tres)
#
# a) Un DataFrame tiene múltiples columnas; una Series tiene una.
# b) Una Series puede tener múltiples índices; un DataFrame no.
# c) Un DataFrame puede contener diferentes tipos de datos en diferentes columnas.
# d) Una Series es bidimensional; un DataFrame es unidimensional.
# Respuestas correctas: a), b), c)
#
# ⸻
#
# Sección 2: Habilidades de Programación
#
# 3. ¿Qué método de Pandas es más eficiente para verificar rápidamente los tipos de datos en un conjunto de datos con múltiples columnas de diferentes tipos de datos?
#
# a) describe()
# b) dtypes
# c) type()
# d) values
# e) info()
# Respuesta correcta: e) info()
#
# ⸻
#
# 4. ¿Cuál de las siguientes opciones es una forma correcta de importar la biblioteca NumPy en Python?
#
# a) import numpy as np
# b) from numpy import *
# c) import NumPy
# d) include numpy
# Respuesta correcta: a) import numpy as np
#
# ⸻
#
# Sección 3: Conocimientos Estadísticos
#
# 5. ¿Qué medida estadística es más adecuada para describir la tendencia central de un conjunto de datos con valores atípicos extremos?
#
# a) Media
# b) Mediana
# c) Moda
# d) Rango
# Respuesta correcta: b) Mediana
#
# ⸻
#
# 6. ¿Cuál de las siguientes afirmaciones sobre la correlación es verdadera?
#
# a) Una correlación de 0 indica una fuerte relación lineal.
# b) Una correlación de -1 indica una relación lineal negativa perfecta.
# c) Una correlación de 1.5 es posible en conjuntos de datos reales.
# d) La correlación mide la causalidad entre dos variables.
# Respuesta correcta: b) Una correlación de -1 indica una relación lineal negativa perfecta.
#
# ⸻
#
# Sección 4: Análisis y Modelado de Datos
#
# 7. ¿Qué función de Pandas se utiliza para agrupar datos y aplicar funciones de agregación?
#
# a) groupby()
# b) aggregate()
# c) merge()
# d) concat()
# Respuesta correcta: a) groupby()
#
# ⸻
#
# 8. ¿Cuál de las siguientes opciones es una técnica de reducción de dimensionalidad?
#
# a) Regresión lineal
# b) Análisis de componentes principales (PCA)
# c) Árboles de decisión
# d) K-means
# Respuesta correcta: b) Análisis de componentes principales (PCA)
#
# ⸻
#
# Sección 5: Visualización y Reporte de Datos
#
# 9. ¿Qué biblioteca de Python se utiliza comúnmente para crear gráficos estadísticos atractivos y fáciles de interpretar?
#
# a) Matplotlib
# b) Seaborn
# c) Plotly
# d) Bokeh
# Respuesta correcta: b) Seaborn
#
# ⸻
#
# 10. ¿Cuál de los siguientes gráficos es más adecuado para visualizar la distribución de una variable numérica?
#
# a) Gráfico de barras
# b) Diagrama de caja (boxplot)
# c) Gráfico de líneas
# d) Gráfico de dispersión
# Respuesta correcta: b) Diagrama de caja (boxplot)
#
# ⸻
#
# 📚 Recursos Adicionales para Preparación
# 	•	Edusum ofrece preguntas de muestra y exámenes de práctica para el PCED:  ￼
# 	•	MyExamCloud proporciona simuladores de examen y guías de estudio para el PCED-30-01:  ￼
# 	•	ExamsDigest ofrece exámenes de práctica con más de 600 preguntas para el PCED:  ￼
